# %%
from dictionaries import load_main_config, load_state, load_data, build_main_diagnoses, pack_dictionary

# %%
if __name__ == '__main__':

    STATE_PATH, output_cols, dictionary_path, data_path, sql, write_path = load_main_config()
    data = load_data(data_path, sql)
    load_state(STATE_PATH)
    main_diagnoses = build_main_diagnoses(data, output_cols, dictionary_path, STATE_PATH)
    pack_dictionary(main_diagnoses, write_path)

# %%
pack_dictionary(main_diagnoses, write_path)

# %%
from dictionaries import get_concept
special = get_concept('55822004')
special
# Out:
# {}

# %%
data.loc['15af65cf-4023-109b-9a33-1d136822a0c6']
# Out:
#                                       diagnosis1   diagnosis2  diagnosis3  \
# id
# 15af65cf-4023-109b-9a33-1d136822a0c6   314529007  160903007.0  73595000.0
#
#                                         diagnosis4  diagnosis5  diagnosis6  \
# id
# 15af65cf-4023-109b-9a33-1d136822a0c6  1.093988e+16         NaN         NaN
#
#                                       diagnosis7  diagnosis8
# id
# 15af65cf-4023-109b-9a33-1d136822a0c6         NaN         NaN
