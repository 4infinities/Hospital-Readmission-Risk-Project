# %%
from dictionaries import load_main_config, load_state, load_data, build_main_diagnoses, pack_dictionary

# %%
if __name__ == '__main__':

    STATE_PATH, output_cols, dictionary_path, data_path, sql, write_path = load_main_config(source_type = 'test')
    data = load_data(data_path, sql)
    load_state(STATE_PATH)
    main_diagnoses = build_main_diagnoses(data, output_cols, dictionary_path, STATE_PATH)
    pack_dictionary(main_diagnoses, write_path)

# %%
pack_dictionary(main_diagnoses, write_path)

# %%
from dictionaries import get_concept
special = get_concept('55822004')
special
# Out:
# {}

# %%
main_diagnoses
# Out:
#                                       num_of_disorders  num_of_findings  \
# id
# 000085c1-5b07-25b7-201f-9c07bd2d8a2c                 2                0
# 000085c1-5b07-25b7-220f-22a71883077d                 1                0
# 000085c1-5b07-25b7-2b96-95f0a0eb34a6                 0                0
# 000085c1-5b07-25b7-3b3d-7d3617753f2b                 1                0
# 000085c1-5b07-25b7-5449-7786c06ccb23                 1                0
# ...                                                ...              ...
# ffff0666-1c11-89c7-8f12-828c483ad44b                 1                0
# ffff0666-1c11-89c7-a103-791dbd4758eb                 1                0
# ffff0666-1c11-89c7-ab3f-d4e3022bf742                 1                0
# ffff0666-1c11-89c7-c1a3-d0613b3601ce                 2                0
# ffff0666-1c11-89c7-f85a-84e3fef2c5fa                 1                0
#
#                                      main_diagnosis_code main_diagnosis_type  \
# id
# 000085c1-5b07-25b7-201f-9c07bd2d8a2c           109570002            disorder
# 000085c1-5b07-25b7-220f-22a71883077d           195662009            disorder
# 000085c1-5b07-25b7-2b96-95f0a0eb34a6
# 000085c1-5b07-25b7-3b3d-7d3617753f2b            66383009            disorder
# 000085c1-5b07-25b7-5449-7786c06ccb23           195662009            disorder
# ...                                                  ...                 ...
# ffff0666-1c11-89c7-8f12-828c483ad44b           427898007            disorder
# ffff0666-1c11-89c7-a103-791dbd4758eb           444814009            disorder
# ffff0666-1c11-89c7-ab3f-d4e3022bf742           444814009            disorder
# ffff0666-1c11-89c7-c1a3-d0613b3601ce            75498004            disorder
# ffff0666-1c11-89c7-f85a-84e3fef2c5fa            66383009            disorder
#
#                                                 main_diagnosis_name
# id
# 000085c1-5b07-25b7-201f-9c07bd2d8a2c          Primary dental caries
# 000085c1-5b07-25b7-220f-22a71883077d        Acute viral pharyngitis
# 000085c1-5b07-25b7-2b96-95f0a0eb34a6
# 000085c1-5b07-25b7-3b3d-7d3617753f2b                     Gingivitis
# 000085c1-5b07-25b7-5449-7786c06ccb23        Acute viral pharyngitis
# ...                                                             ...
# ffff0666-1c11-89c7-8f12-828c483ad44b  Infection of tooth (disorder)
# ffff0666-1c11-89c7-a103-791dbd4758eb     Viral sinusitis (disorder)
# ffff0666-1c11-89c7-ab3f-d4e3022bf742     Viral sinusitis (disorder)
# ffff0666-1c11-89c7-c1a3-d0613b3601ce      Acute bacterial sinusitis
# ffff0666-1c11-89c7-f85a-84e3fef2c5fa                     Gingivitis
#
# [802079 rows x 5 columns]
