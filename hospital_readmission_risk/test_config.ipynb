# %%
from config import credentials, data_path
from data import load_data, filter_dates

# %%
df = load_data(data_path)

# %%
df = filter_dates(df)

# %%
df
# Out:
#                                   patient_id  patient_age gender  \
# 0       f4fe3c13-9369-202a-7e43-5dc06ef7f91f           64      M
# 1       71ed9b55-a628-0008-7568-b41bb15b20dc           58      M
# 2       be14c46c-ddb4-29b3-d795-1bc541cf5f56            3      M
# 4       c4ef12ca-bd1b-8685-567e-19c7a06a9db8           22      F
# 6       32f5456f-364a-5a66-4cba-dea7029d14fd           72      F
# ...                                      ...          ...    ...
# 109493  ffe8daf6-b1cb-4558-e92c-466e256350ac           70      F
# 109494  ffe8daf6-b1cb-4558-e92c-466e256350ac           71      F
# 109495  ffe8daf6-b1cb-4558-e92c-466e256350ac           71      F
# 109496  ffe8daf6-b1cb-4558-e92c-466e256350ac           73      F
# 109497  ffe8daf6-b1cb-4558-e92c-466e256350ac           72      F
#
#                                      stay_id  \
# 0       f4fe3c13-9369-202a-fabd-af6072d1b8e1
# 1       71ed9b55-a628-0008-28bb-2e30a6e65ec5
# 2       be14c46c-ddb4-29b3-820a-efa9f06fabad
# ...
