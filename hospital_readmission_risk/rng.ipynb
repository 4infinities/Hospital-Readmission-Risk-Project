# %%
import pandas as pd

# %%
d = {'a' : 1.2,
    'b' : 2.3,
    'c' : 3.4}

model = 'F'
frame = pd.DataFrame(d, index = [model]).T

e = {'a' : 2.3,
    'b' : 3.4}

f = {'c' : 4.5}

#pd.concat([frame, pd.Series(e.update(f))])
e.update(f)
#frame.T.join(pd.Series(e, index = 'G'))

frame['G'] = pd.Series(e)

frame
# Out:
#      F    G
# a  1.2  2.3
# b  2.3  3.4
# c  3.4  4.5
